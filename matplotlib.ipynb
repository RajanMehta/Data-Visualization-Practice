# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1, 1, 2, 2, 4, 9, 5, 3])     #y-axis. index work as x-axis
plt.show()

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3]) #x-axis, y-axis
plt.show()

# %%
plt.plot([-3, -2, 5, 0], [1, 6, 4, 3])
plt.axis([-4, 6, 0, 7])     #[xmin, xmax, ymin, ymax]
plt.show()

# %%
import numpy as np
x = np.linspace(-2, 2, 100)  #100 evenly spaced numbers over between interval -2 to 2
y = x**2

plt.plot(x, y, "g--") #green dashed line

plt.title("Square function")
plt.xlabel("x")
plt.ylabel("y = x**2")
plt.grid(True)

plt.show()

# %%
#https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.plot

x1 = np.linspace(-2, 2, 100)  #100 evenly spaced numbers over between interval -2 to 2
y1 = x**2

x2 = np.linspace(-1, 1, 100)  #100 evenly spaced numbers over between interval -2 to 2
y2 = x**2

plt.plot(x1, y1, "g--",x2, y2, "m-")

plt.title("Square function")
plt.xlabel("x")
plt.ylabel("y = x**2")
plt.grid(True)

plt.show()
#plt.savefig("my_square_function.png", transparent=True)

# %%
x = np.linspace(-1.4, 1.4, 30)

#can also plot one at a time
plt.plot(x, x, 'g--', linewidth=2.0)    #https://matplotlib.org/users/pyplot_tutorial.html#controlling-line-properties
plt.plot(x, x**2, 'r:')
plt.plot(x, x**3, 'b^')
plt.show()

# %%
x = np.linspace(-1.4, 1.4, 30)
plt.subplot(2, 2, 1)  # 2 rows, 2 columns, 1st subplot = top left
plt.plot(x, x)
plt.subplot(2, 2, 2)  # 2 rows, 2 columns, 2nd subplot = top right
plt.plot(x, x**2)
plt.subplot(2, 2, 3)  # 2 rows, 2 columns, 3rd subplot = bottow left
plt.plot(x, x**3)
plt.subplot(2, 2, 4)  # 2 rows, 2 columns, 4th subplot = bottom right
plt.plot(x, x**4)
plt.show()

# %%
plt.subplot2grid((3,3), (0, 0), rowspan=2, colspan=2)
plt.plot(x, x**2)
plt.subplot2grid((3,3), (0, 2))
plt.plot(x, x**3, "r-")
plt.subplot2grid((3,3), (1, 2), rowspan=2)
plt.plot(x, x**4, "m-")
plt.subplot2grid((3,3), (2, 0), colspan=2)
plt.plot(x, x**5, "g-")
plt.show()

# %%
x = np.linspace(-1.4, 1.4, 30)

plt.figure(1)
plt.subplot(211)
plt.plot(x, x**2)
plt.title("Square and Cube")
plt.subplot(212)
plt.plot(x, x**3)

plt.figure(2, figsize=(10, 5))
plt.subplot(121)
plt.plot(x, x**4)
plt.title("y = x**4")
plt.subplot(122)
plt.plot(x, x**5)
plt.title("y = x**5")

plt.figure(1)      # back to figure 1, current subplot is 212 (bottom)
plt.plot(x, -x**3, "r:")

plt.show()

# %%
#https://matplotlib.org/users/text_props.html#text-properties

x = np.linspace(-1.5, 1.5, 30)
px = 0.8
py = px**2

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='blue', horizontalalignment="center")
plt.text(px-0.05, py, "Beautiful point", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny = %0.2f"%(px, py), rotation=50, color='gray')

plt.plot(x, x**2, "b-", px, py, "ro")

# %%
plt.plot(x, x**2, px, py, "ro")
plt.annotate("Beautiful point", xy=(px, py), xytext=(px-1.3,py+0.5),
                           color="green", weight="heavy", fontsize=14,
                           arrowprops={"facecolor": "lightgreen"})
plt.show()

# %%
#https://matplotlib.org/api/_as_gen/matplotlib.patches.BoxStyle.html

plt.plot(x, x**2, px, py, "ro")

bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
plt.text(px-0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

bbox_props = dict(boxstyle="round4,pad=1,rounding_size=0.2", ec="black", fc="#f2f2f2", lw=2)
plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=15, color='black', ha="center", bbox=bbox_props)

plt.show()

# %%
with plt.xkcd():
    plt.plot(x, x**2, px, py, "ro")
    
    bbox_props = dict(boxstyle="rarrow,pad=0.3", ec="b", lw=2, fc="lightblue")
    plt.text(px-0.2, py, "Beautiful point", bbox=bbox_props, ha="right")

    bbox_props = dict(boxstyle="round4,pad=0.7,rounding_size=0.2", ec="black", fc="#EEEEFF", lw=2)
    plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=15, color='black', ha="center", bbox=bbox_props)
    
    plt.show()

# %%
plt.rcdefaults()
# %matplotlib inline

# %%
x = np.linspace(-1.4, 1.4, 50)
plt.plot(x, x**2, "r--", label="Square function")
plt.plot(x, x**3, "g-", label="Cube function")
plt.legend(loc="best")
plt.grid(True)
plt.show()

# %%
x = np.linspace(0.1, 15, 500)
y = x**3/np.exp(2*x)

plt.figure(1)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)

plt.figure(2)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)

plt.figure(4)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthreshy=0.05)
plt.title('symlog')
plt.grid(True)

plt.show()

# %%
x = np.linspace(-2, 2, 100)

plt.figure(1, figsize=(12,7))
plt.subplot(131)
plt.plot(x, x**3)
plt.grid(True)
plt.title("Default ticks")

ax = plt.subplot(132)
plt.plot(x, x**3)
ax.xaxis.set_ticks(np.arange(-2, 2, 1))
plt.grid(True)
plt.title("Manual ticks on the x-axis")

ax = plt.subplot(133)
plt.plot(x, x**3)
plt.minorticks_on()
ax.tick_params(axis='x', which='minor', bottom='off')
ax.xaxis.set_ticks([-2, 0, 1, 2])
ax.yaxis.set_ticks(np.arange(-5, 5, 1))
ax.yaxis.set_ticklabels(["min", -4, -3, -2, -1, 0, 1, 2, 3, "max"])
plt.title("Manual ticks and tick labels\n(plus minor ticks) on the y-axis")


plt.grid(True)

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
from numpy.random import rand
x, y = rand(2, 100)
plt.scatter(x, y)
plt.show()

# %%
x, y, scale = rand(3, 100)
scale = 500 * scale ** 5
plt.scatter(x, y, s=scale)
plt.show()

# %%
for color in ['red', 'green', 'blue']:
    x, y, scale = rand(3, 100)
    scale = 500 * scale ** 5
    plt.scatter(x, y, s=scale, c=color, alpha=0.3, edgecolors='blue')

plt.grid(True)

plt.show()

# %%
from numpy.random import randn

def plot_line(axis, slope, intercept, **kargs):
    xmin, xmax = axis.get_xlim()
    plt.plot([xmin, xmax], [xmin*slope+intercept, xmax*slope+intercept], **kargs)

x = randn(1000)
y = 0.5*x + 5 + randn(1000)*2
plt.axis([-2.5, 2.5, -5, 15])
plt.scatter(x, y, alpha=0.2)
plt.plot(1, 0, "ro")
plt.vlines(1, -5, 0, color="red")
plt.hlines(0, -2.5, 1, color="red")
plot_line(axis=plt.gca(), slope=0.5, intercept=5, color="magenta")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Histograms

# %%
data = [1, 1.1, 1.8, 2, 2.1, 3.2, 3, 3, 3, 3, 1.25]
plt.subplot(211)
plt.hist(data, bins = 10, rwidth=0.8)  #rwidth: The relative width of the bars as a fraction of the bin width

plt.subplot(212)
plt.hist(data, bins = [1, 1.5, 2, 2.5, 3], rwidth=0.95)
plt.xlabel("Value")
plt.ylabel("Frequency")

plt.show()

# %%
data1 = np.random.randn(400)
data2 = np.random.randn(500) + 3
data3 = np.random.randn(450) + 6
data4a = np.random.randn(200) + 9
data4b = np.random.randn(100) + 10

plt.hist(data1, bins=5, color='g', alpha=0.75, label='bar hist') # default histtype='bar'
plt.hist(data2, color='b', alpha=0.65, histtype='stepfilled', label='stepfilled hist')
plt.hist(data3, color='r', histtype='step', label='step hist')
plt.hist((data4a, data4b), color=('r','m'), alpha=0.55, histtype='barstacked', label=('barstacked a', 'barstacked b'))

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend(loc="best")
plt.grid(True)
plt.show()
